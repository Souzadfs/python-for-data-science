# %% [markdown]
# <a href="https://colab.research.google.com/github/Souzadfs/python-for-data-science/blob/main/Analista_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as py
import matplotlib.pyplot as plot
import seaborn as sns
import datetime as dt

# %%
df = pd.read_csv('global_tech_salary.txt')

# %% [markdown]
# **Visualização da base importada**

# %%
df.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2023               MI              FT               Data Analyst
# 1       2023               MI              FT               Data Analyst
# 2       2024               MI              FT  Machine Learning Engineer
# 3       2024               SE              FT             Data Scientist
# 4       2023               MI              FT          Research Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  165000             USD         165000                 AU             0
# 1   70000             USD          70000                 US           100
# 2   85000             EUR          94444                 IE           100
# 3   92700             USD          92700                 US             0
# 4  150000             USD         150000                 US             0
#
#   company_location company_size
# 0               AU            M
# 1               US            M
# 2               IE            M
# 3               US            M
# 4               US            M

# %%
df.tail()
# Out:
#       work_year experience_level employment_type  \
# 4995       2023               SE              FT
# 4996       2022               SE              FT
# 4997       2024               SE              FT
# 4998       2022               EN              FT
# 4999       2023               SE              FT
#
#                                      job_title  salary salary_currency  \
# 4995  Machine Learning Infrastructure Engineer   70000             EUR
# 4996                             Data Engineer  145000             USD
# 4997                 Machine Learning Engineer  153000             USD
# 4998                              AI Scientist   30000             EUR
# 4999                 Machine Learning Engineer  176000             USD
#
#       salary_in_usd employee_residence  remote_ratio company_location  \
# 4995          75577                 FR           100               FR
# 4996         145000                 US             0               US
# 4997         153000                 US             0               US
# 4998          31520                 PT           100               ES
# 4999         176000                 US             0               US
#
#      company_size
# 4995            M
# 4996            M
# 4997            M
# 4998            M
# 4999            M

# %%
df.shape
# Out:
# (5000, 11)

# %% [markdown]
# **Periodo da análise**

# %%
inicio = pd.to_datetime(df['work_year']).dt.date.min()
print(inicio)
# Out:
# 1970-01-01

# %%
fim = pd.to_datetime(df['work_year']).dt.date.max()
print(fim)
# Out:
# 1970-01-01

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           5000 non-null   int64
#  1   experience_level    5000 non-null   object
#  2   employment_type     5000 non-null   object
#  3   job_title           5000 non-null   object
#  4   salary              5000 non-null   int64
#  5   salary_currency     5000 non-null   object
#  6   salary_in_usd       5000 non-null   int64
#  7   employee_residence  5000 non-null   object
#  8   remote_ratio        5000 non-null   int64
#  9   company_location    5000 non-null   object
#  10  company_size        5000 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 429.8+ KB

# %%
df.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df[df['salary']>=250000]
# Out:
#       work_year experience_level employment_type                  job_title  \
# 26         2023               SE              FT         Analytics Engineer
# 31         2021               EN              FT             Data Scientist
# 42         2024               EN              FT           Research Analyst
# 45         2023               MI              FT  Machine Learning Engineer
# 81         2023               SE              FT  Machine Learning Engineer
# ...         ...              ...             ...                        ...
# 4926       2023               SE              FT             Data Scientist
# 4931       2024               EX              FT               Data Science
# 4949       2023               SE              FT  Machine Learning Engineer
# 4958       2024               SE              FT  Machine Learning Engineer
# 4976       2024               EX              FT               Head of Data
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 26     275300             USD         275300                 US           100
# 31    2100000             INR          28399                 IN           100
# 42     300000             USD         300000                 US             0
# 45     300000             USD         300000                 US             0
# 81     264400             USD         264400                 US           100
# ...       ...             ...            ...                ...           ...
# 4926   297300             USD         297300                 US           100
# 4931   300000             USD         300000                 US           100
# 4949   311000             USD         311000                 US             0
# 4958   257000             USD         257000                 US             0
# 4976   290000             USD         290000                 US           100
#
#      company_location company_size
# 26                 US            M
# 31                 IN            M
# 42                 US            M
# 45                 US            M
# 81                 US            M
# ...               ...          ...
# 4926               US            M
# 4931               US            M
# 4949               US            M
# 4958               US            M
# 4976               US            M
#
# [378 rows x 11 columns]

# %%
base_excel = df[df['salary']>=80000]
base_excel.to_excel('base_excel.xlsx')

# %%
df.salary.value_counts()
# Out:
# salary
# 100000    101
# 150000    101
# 120000    100
# 130000     93
# 160000     77
#          ...
# 61700       1
# 289000      1
# 130400      1
# 86026       1
# 149094      1
# Name: count, Length: 1301, dtype: int64
